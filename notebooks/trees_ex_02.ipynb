# %% [markdown]
# # 📝 Exercise M5.02
#
# The aim of this exercise is to find out whether a decision tree
# model is able to extrapolate.
#
# By extrapolation, we refer to values predicted by a model outside of the
# range of feature values seen during the training.
#
# We will first load the regression data.

# %%
import pandas as pd

penguins = pd.read_csv("../datasets/penguins_regression.csv")

feature_name = "Flipper Length (mm)"
target_name = "Body Mass (g)"
data_train, target_train = penguins[[feature_name]], penguins[target_name]

# %% [markdown]
# <div class="admonition note alert alert-info">
# <p class="first admonition-title" style="font-weight: bold;">Note</p>
# <p class="last">If you want a deeper overview regarding this dataset, you can refer to the
# Appendix - Datasets description section at the end of this MOOC.</p>
# </div>

# %% [markdown]
# First, create two models, a linear regression model and a decision tree
# regression model, and fit them on the training data. Limit the depth at
# 3 levels for the decision tree.

# %%
# Write your code here.
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

linear_mode = LinearRegression()
linear_mode.fit(data_train, target_train)

tree = DecisionTreeRegressor(max_depth=3)
tree.fit(data_train, target_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %% [markdown]
# Create a synthetic dataset containing all possible flipper length from
# the minimum to the maximum of the training dataset. Get the predictions of
# each model using this dataset.

# %%
# Write your code here.
import numpy as np

flipper_length_test = pd.DataFrame(np.linspace(data_train.min(), data_train.max(), 100), columns=["Flipper Length (mm)"])

linear_predict = linear_mode.predict(flipper_length_test)
tree_predict = tree.predict(flipper_length_test)

# %% [markdown]
# Create a scatter plot containing the training samples and superimpose the
# predictions of both models on the top.

# %%
# Write your code here.
import seaborn as sns
import matplotlib.pyplot as plt

print(flipper_length_test.shape, linear_predict.shape)

sns.scatterplot(data_train.iloc[:, 0], target_train, color="k", alpha=0.5)
sns.lineplot(flipper_length_test.iloc[:, 0], linear_predict, label="linear model")
sns.lineplot(flipper_length_test.iloc[:, 0], tree_predict, label="tree model")

plt.legend()
# Out:
# (100, 1) (100,)
# C:\Users\bruce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bruce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bruce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %% [markdown]
# Now, we will check the extrapolation capabilities of each model. Create a
# dataset containing a broader range of values than your previous dataset,
# in other words, add values below and above the minimum and the maximum of
# the flipper length seen during training.

# %%
# Write your code here.
flipper_length_test = pd.DataFrame(np.linspace(data_train.min() / 1.5, data_train.max() * 1.5, 100), columns=["Flipper Length (mm)"])

# %% [markdown]
# Finally, make predictions with both models on this new interval of data.
# Repeat the plotting of the previous exercise.

# %%
# Write your code here.
linear_predict = linear_mode.predict(flipper_length_test)
tree_predict = tree.predict(flipper_length_test)

# %%
# Write your code here.
sns.scatterplot(data_train.iloc[:, 0], target_train, color="k", alpha=0.5)
sns.lineplot(flipper_length_test.iloc[:, 0], linear_predict, label="linear model")
sns.lineplot(flipper_length_test.iloc[:, 0], tree_predict, label="tree model")

plt.legend()
# Out:
# C:\Users\bruce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bruce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bruce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
